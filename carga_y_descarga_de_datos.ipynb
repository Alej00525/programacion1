# %% [markdown]
# <a href="https://colab.research.google.com/github/Alej00525/programacion1/blob/main/carga_y_descarga_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# python permite cargar y crear objetos de archivos dados, y tambien permite crear y editar archivos dados.

# %%
with open('archivo.txt',"w") as f:
    f.write("Hola, este es un archivo de tecto.\n")
    f.write("segunda linea.\n")
    f.write("tercera linea.\n")

# %%
with open('archivo.txt',"r") as f:
    print(f.read())
# Out:
# Hola, este es un archivo de tecto.
# segunda linea.
# tercera linea.

# %%
from google.colab import files
files.download('archivo.txt')
#

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-28400995-31de-4425-a4e0-c2886bfa56dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28400995-31de-4425-a4e0-c2886bfa56dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open('mi bombo (1).txt',"r") as f:
    print(f.read())
# Out:
#       ,.,.,.,.,.,
#     .. , , , , , ..
#    ..             ..      c--------------------------------?
#  ..                ..  <<<(  MI BOMB0000000000000          )
# ..     *       *    ..    c--------------------------------?
# .          v         .
# ..                  ..
#  .     ----o----    .
#   ..................

# %%
with open('mi bombo.txt',"w") as f:
    f.write("Hola, este es un archivo modificado jaja.\n")
    f.write("segunda linea mod.\n")
    f.write("tercera linea mod.\n")

# %%
with open('mi bombo (1).txt',"r") as f:
# Out:
#       ,.,.,.,.,.,
#     .. , , , , , ..
#    ..             ..      c--------------------------------?
#  ..                ..  <<<(  MI BOMB0000000000000          )
# ..     *       *    ..    c--------------------------------?
# .          v         .
# ..                  ..
#  .     ----o----    .
#   ..................

# %%
import csv
datos = [
    ['nombre','apellido','edad'],
    ['juan','perez',25],
    ['ana','gomez',30]
]
with open('datos.csv','w',newline='') as f:
    writer = csv.writer(f)
    writer.writerows(datos)

# %%
with open('datos.csv',"r") as f:
    print(f.read())
# Out:
# nombre,apellido,edad
# juan,perez,25
# ana,gomez,30

# %%
files.download('datos.csv')
#

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
ruta = "/content/drive/MyDrive/datos.csv"
import shutil
shutil.copy('datos.csv', ruta)
# Out:
# '/content/drive/MyDrive/datos.csv'

# %%
with open(ruta,'r') as f:
    print(f.read())
# Out:
# nombre,apellido,edad
# juan,perez,25
# ana,gomez,30

# %%
with open(ruta,'r') as f:
  data = list(csv.reader(f))
data.append(['pedro','lopez',35])
data
# Out:
# [['nombre', 'apellido', 'edad'],
#  ['juan', 'perez', '25'],
#  ['ana', 'gomez', '30'],
#  ['pedro', 'lopez', '35'],
#  ['pedro', 'lopez', '35'],
#  ['pedro', 'lopez', 35]]

# %%
import csv
ruta = '/content/drive/MyDrive/datos.csv'
with open(ruta,'r') as f:
  data = list(csv.reader(f))
data
# Out:
# [['nombre', 'apellido', 'edad'],
#  ['juan', 'perez', '25'],
#  ['ana', 'gomez', '30'],
#  ['pedro', 'lopez', '35'],
#  ['pedro', 'lopez', '35']]

# %%
import os
os.listdir
